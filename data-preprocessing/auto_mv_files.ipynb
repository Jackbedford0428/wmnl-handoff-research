# %% [markdown]
# # Description
#
# This is an automation script to categorize raw data captured in each experiment.
#
# This script can be divided into four parts:
#
# - Stage 0: User Settings: Modify settings to fit your experiment data.
# - Stage 1: Collect metadata.
# - Stage 2: Check files to make sure the numbers of each type of files are reasonable.
# - Stage 3: Categorize files in chronological order, and organize with experiment names.
#
# Before you go to stage 3, make sure you have already uploaded (manually or using py-script) all the raw data to database into specific directories, and removed the redundant files manually.

# %%
import os
import yaml
import shutil

# ===================== User Settings =====================
dates = [
    # "2024-03-19",
    "2024-03-20",
]

target_folders = [
    "mi2log",
    "mi2log_xml",
    "server_pcap",
    "client_pcap",
]

common_folders = [
    "gps",
    "sync",
]

# ===================== Utils =====================
def makedir(dirpath):
    if not os.path.isdir(dirpath):
        print('    makedir:', dirpath)
        os.makedirs(dirpath)

def savecopy(filepath, targetdir, filename):
    # filename can be different from basename of filepath, can be used to rename a file.
    makedir(targetdir)
    print("    cp -p", filepath, os.path.join(targetdir, filename))
    shutil.copy2(filepath, os.path.join(targetdir, filename))  # reserve the last modified datetime and other metadata

def savemove(filepath, targetdir, filename):
    # filename can be different from basename of filepath, can be used to rename a file.
    makedir(targetdir)
    print("    mv", filepath, os.path.join(targetdir, filename))
    shutil.move(filepath, os.path.join(targetdir, filename))

# def delete(filepath):
#     if not os.path.exists(filepath):
#         print("rm: '{}': No such file or directory".format(filepath))
#         return
#     print("rm", filepath)
#     os.remove(filepath)

# def movedir(dirpath, targetdir, dirname):
#     # dirname can be different from basename of dirpath, can be used to rename a directory.
#     makedir(targetdir)
#     print("mv", dirpath, os.path.join(targetdir, dirname))
#     shutil.move(dirpath, os.path.join(targetdir, dirname))

# def copydir(dirpath, targetdir, dirname):
#     # dirname can be different from basename of dirpath, can be used to rename a directory.
#     makedir(targetdir)
#     print("copy", dirpath, os.path.join(targetdir, dirname))
#     shutil.copytree(dirpath, os.path.join(targetdir, dirname))

def deletedir_empty(dirpath):
    if not os.path.exists(dirpath):
        print("rmdir: '{}': No such file or directory".format(dirpath))
        return
    print("rmdir", dirpath)
    os.rmdir(dirpath)

# def deletedir_nonempty(dirpath):
#     if not os.path.exists(dirpath):
#         print("rm -rf: '{}': No such file or directory".format(dirpath))
#         return
#     print("rm -rf", dirpath)
#     shutil.rmtree(dirpath, ignore_errors=True)

# %% [markdown]
# # Stage 1: Collect Metadata

# %%
dates = sorted(dates)
with open(os.path.join(os.getcwd(), "db_path.txt"), "r") as f:
        PATHS_TO_DATABASE = [s.strip() for s in f.readlines()]
    
date_paths = []

for date in dates:
    not_found_in_database = []
    
    for db_path in PATHS_TO_DATABASE:
        date_path = os.path.join(db_path, date)
        if os.path.isdir(date_path):
            date_paths.append(date_path)
        else:
            not_found_in_database.append(date_path)
    
    if len(not_found_in_database) == len(PATHS_TO_DATABASE):
        error_message = "[Errno 2] No such file or directory:\n"
        for date_path in not_found_in_database:
            error_message += "  '{}'\n".format(date_path)
        raise FileNotFoundError(error_message.strip())

metadatas = {}

for i, date_path in enumerate(date_paths):
    print('------------------')
    print(os.path.basename(date_path), ': ', os.path.dirname(date_path), sep='')
    
    yml_file = os.path.join(date_path, os.path.basename(date_path) + '.yml')
    with open(yml_file, 'r') as f:
        data = yaml.safe_load(f)
    
    metadatas[date_path] = [0]
    
    for j, (exp_name, exp) in enumerate(data.items()):
        if j > 0: print('  ------------------')
        print(' ', exp_name, '->', 'Skip:', exp['skip'], '|', 'UE:', exp['ue'], '|', 'Laptop:', exp['laptop'], '|', 'Route:', exp['route'])
        print('   ', exp['devices'])
        if exp['skip']:
            continue
        trips = []
        for key, value in exp['ods'].items():
            print('     ', key, value)
            if key > 0: trips.append(f'#{key:02d}')
        
        metadatas[date_path].append({
            'exp_name': exp_name,
            'ue': exp['ue'],
            'laptop': exp['laptop'],
            'route': exp['route'],
            'devices': list(exp['devices']),
            'trips': trips[:]
        })
        metadatas[date_path][0] += len(trips)
    
    if i == len(date_paths) - 1: print('------------------')
# Out:
# ------------------
# 2024-03-20: /home/wmnlab/F/database
#   UDP_Bandlock_9S_Phone_A -> Skip: False | UE: Phone | Laptop: lpt3 | Route: A
#     {'sm00': 'All', 'sm01': 'All', 'sm02': 'B1B3', 'sm03': 'B1B7', 'sm04': 'B1B8', 'sm05': 'B3B7', 'sm06': 'B3B8', 'sm07': 'B7B8', 'sm08': 'LTE'}
#       0 ['起站', '迄站', '出發時間(hh:mm)', '備註']
#       1 ['台北車站', '老街溪', '18:39', ['滿1hr程式中止', 'sm03 pcap 只記錄到大概 1-2 分鐘左右的資料，mobileinsight 卻沒事']]
#       2 ['環北', '台北車站', '19:56', ['環北開始實驗，新北產業園區前約 19:17 左右，滿1hr程式中止']]
# ------------------

# %% [markdown]
# # Stage 2: Check Files
#
# 檢查資料的數量是否正確
#
# - mi2log, mi2log_xml: 機台數量*總趟次
# - client_pcap: 機台數量*總趟次 (Bilink)
# - server_pcap: 機台數量*總趟次\*2 or 1 (Uplink/Downlink, Bi-link)

# %%
for i, (date_path, metadata) in enumerate(metadatas.items()):
    print('------------------')
    print(date_path, '({})'.format(metadata[0]))
    
    for j, exp in enumerate(metadata[1:]):
        if j > 0: print('  ------------------')
        print(' ', exp['exp_name'], '->', 'UE:', exp['ue'], '|', 'Laptop:', exp['laptop'], '|', 'Route:', exp['route'])
        print('   ', len(exp['devices']), exp['devices'])
        print('     ', len(exp['trips']), exp['trips'])
    
    for target_folder in target_folders:
        filenames = sorted(os.listdir(os.path.join(date_path, target_folder)))
        print('  ------------------')
        print(' ', target_folder, '({})'.format(len(filenames)))
        for filename in filenames:
            print('   ', filename)
    
    for common_folder in common_folders:
        filenames = sorted(os.listdir(os.path.join(date_path, common_folder)))
        print('  ------------------')
        print(' ', common_folder, '({})'.format(len(filenames)))
        for filename in filenames:
            print('   ', filename)
    
    if i == len(date_paths) - 1: print('------------------')
# Out:
# ------------------
# /home/wmnlab/F/database/2024-03-20 (2)
#   UDP_Bandlock_9S_Phone_A -> UE: Phone | Laptop: lpt3 | Route: A
#     9 ['sm00', 'sm01', 'sm02', 'sm03', 'sm04', 'sm05', 'sm06', 'sm07', 'sm08']
#       2 ['#01', '#02']
#   ------------------
#   mi2log (18)
#     diag_log_sm00_2024-03-20_15-23-10.mi2log
#     diag_log_sm00_2024-03-20_18-05-42.mi2log
#     diag_log_sm01_2024-03-20_15-23-10.mi2log
#     diag_log_sm01_2024-03-20_18-05-42.mi2log
#     server_pcap_BL_sm08_3216_3217_2024-03-20_18-05-37_sock.pcap
#   ------------------
#   client_pcap (18)
#     client_pcap_BL_sm00_3200_3201_2024-03-20_15-23-05_sock.pcap
#     client_pcap_BL_sm00_3200_3201_2024-03-20_18-05-36_sock.pcap
#     client_pcap_BL_sm01_3202_3203_2024-03-20_15-23-04_sock.pcap
#     client_pcap_BL_sm01_3202_3203_2024-03-20_18-05-35_sock.pcap
#     client_pcap_BL_sm02_3204_3205_2024-03-20_15-23-06_sock.pcap
#     client_pcap_BL_sm02_3204_3205_2024-03-20_18-05-37_sock.pcap
#     client_pcap_BL_sm03_3206_3207_2024-03-20_15-23-05_sock.pcap
#     client_pcap_BL_sm03_3206_3207_2024-03-20_18-05-36_sock.pcap
#     client_pcap_BL_sm04_3208_3209_2024-03-20_15-23-06_sock.pcap
#     client_pcap_BL_sm04_3208_3209_2024-03-20_18-05-37_sock.pcap
#     client_pcap_BL_sm05_3210_3211_2024-03-20_15-23-05_sock.pcap
#     client_pcap_BL_sm05_3210_3211_2024-03-20_18-05-37_sock.pcap
#     client_pcap_BL_sm06_3212_3213_2024-03-20_15-23-05_sock.pcap
#     client_pcap_BL_sm06_3212_3213_2024-03-20_18-05-36_sock.pcap
#     client_pcap_BL_sm07_3214_3215_2024-03-20_15-23-05_sock.pcap
#     client_pcap_BL_sm07_3214_3215_2024-03-20_18-05-36_sock.pcap
#     client_pcap_BL_sm08_3216_3217_2024-03-20_15-23-06_sock.pcap
#     client_pcap_BL_sm08_3216_3217_2024-03-20_18-05-37_sock.pcap
#   ------------------
#   gps (9)
#     gps_sm00_2024-03-20_145921_Taipei.csv
#     gps_sm01_2024-03-20_145943_Taipei.csv
#     gps_sm02_2024-03-20_150122_Taipei.csv
#     gps_sm03_2024-03-20_150138_Taipei.csv
#     gps_sm04_2024-03-20_150219_Taipei.csv
#     gps_sm05_2024-03-20_150235_Taipei.csv
#     gps_sm06_2024-03-20_150247_Taipei.csv
#     gps_sm07_2024-03-20_150300_Taipei.csv
#     gps_sm08_2024-03-20_150159_Taipei.csv
#   ------------------
#   sync (10)
#     time_sync_lpt3.json
#     time_sync_sm00.json
#     time_sync_sm01.json
#     time_sync_sm02.json
#     time_sync_sm03.json
#     time_sync_sm04.json
#     time_sync_sm05.json
#     time_sync_sm06.json
#     time_sync_sm07.json
#     time_sync_sm08.json
# ------------------

# %% [markdown]
# # Stage 3: Categorize

# %%
for i, (date_path, metadata) in enumerate(metadatas.items()):
    print('------------------')
    print(date_path, '({})'.format(metadata[0]))
    
    for j, exp in enumerate(metadata[1:]):
        if j > 0: print('  ------------------')
        print(' ', exp['exp_name'], '->', 'UE:', exp['ue'], '|', 'Laptop:', exp['laptop'], '|', 'Route:', exp['route'])
        print('   ', len(exp['devices']), exp['devices'])
        print('     ', len(exp['trips']), exp['trips'])
        for target_folder in target_folders:
            src_dirpath = os.path.join(date_path, target_folder)
            print('  ------------------')
            print(' ', target_folder, '({})'.format(len(os.listdir(src_dirpath))))
            for dev in exp['devices']:
                print('   ---', dev)
                filenames = sorted([s for s in os.listdir(src_dirpath) if dev in s])
                for trip in exp['trips']:
                    filename = filenames.pop(0)
                    dest_dirpath = os.path.join(date_path, exp['exp_name'], dev, trip, 'raw')
                    savemove(os.path.join(src_dirpath, filename), dest_dirpath, filename)
    
    if i == len(date_paths) - 1: print('------------------')

for i, (date_path, metadata) in enumerate(metadatas.items()):
    for target_folder in target_folders:
        src_dirpath = os.path.join(date_path, target_folder)
        deletedir_empty(src_dirpath)
# Out:
# ------------------
# /home/wmnlab/F/database/2024-03-20 (2)
#   UDP_Bandlock_9S_Phone_A -> UE: Phone | Laptop: lpt3 | Route: A
#     9 ['sm00', 'sm01', 'sm02', 'sm03', 'sm04', 'sm05', 'sm06', 'sm07', 'sm08']
#       2 ['#01', '#02']
#   ------------------
#   mi2log (18)
#    --- sm00
#     makedir: /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm00/#01/raw
#     mv /home/wmnlab/F/database/2024-03-20/mi2log/diag_log_sm00_2024-03-20_15-23-10.mi2log /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm00/#01/raw/diag_log_sm00_2024-03-20_15-23-10.mi2log
#     makedir: /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm00/#02/raw
#     mv /home/wmnlab/F/database/2024-03-20/mi2log/diag_log_sm00_2024-03-20_18-05-42.mi2log /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm00/#02/raw/diag_log_sm00_2024-03-20_18-05-42.mi2log
#    --- sm01
#     makedir: /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm01/#01/raw
#     mv /home/wmnlab/F/database/2024-03-20/mi2log/diag_log_sm01_2024-03-20_15-23-10.mi2log /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm01/#01/raw/diag_log_sm01_2024-03-20_15-23-10.mi2log
#     makedir: /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm01/#02/raw
#     mv /home/wmnlab/F/database/2024-03-20/mi2log/diag_log_sm01_2024-03-20_18-05-42.mi2log /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm01/#02/raw/diag_log_sm01_2024-03-20_18-05-42.mi2log
#    --- sm02
#     makedir: /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm02/#01/raw
#     mv /home/wmnlab/F/database/2024-03-20/mi2log/diag_log_sm02_2024-03-20_15-23-10.mi2log /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm02/#01/raw/diag_log_sm02_2024-03-20_15-23-10.mi2log
#     makedir: /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm02/#02/raw
#     mv /home/wmnlab/F/database/2024-03-20/mi2log/diag_log_sm02_2024-03-20_18-05-42.mi2log /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm02/#02/raw/diag_log_sm02_2024-03-20_18-05-42.mi2log
#    --- sm03
#     makedir: /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm03/#01/raw
#     mv /home/wmnlab/F/database/2024-03-20/mi2log/diag_log_sm03_2024-03-20_15-23-10.mi2log /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm03/#01/raw/diag_log_sm03_2024-03-20_15-23-10.mi2log
#     makedir: /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm03/#02/raw
#     mv /home/wmnlab/F/database/2024-03-20/mi2log/diag_log_sm03_2024-03-20_18-05-42.mi2log /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm03/#02/raw/diag_log_sm03_2024-03-20_18-05-42.mi2log
#    --- sm04
#     makedir: /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm04/#01/raw
#     mv /home/wmnlab/F/database/2024-03-20/mi2log/diag_log_sm04_2024-03-20_15-23-10.mi2log /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm04/#01/raw/diag_log_sm04_2024-03-20_15-23-10.mi2log
#     makedir: /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm04/#02/raw
#     mv /home/wmnlab/F/database/2024-03-20/mi2log/diag_log_sm04_2024-03-20_18-05-42.mi2log /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm04/#02/raw/diag_log_sm04_2024-03-20_18-05-42.mi2log
#    --- sm05
#     makedir: /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm05/#01/raw
#     mv /home/wmnlab/F/database/2024-03-20/mi2log/diag_log_sm05_2024-03-20_15-23-10.mi2log /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm05/#01/raw/diag_log_sm05_2024-03-20_15-23-10.mi2log
#     makedir: /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm05/#02/raw
#     mv /home/wmnlab/F/database/2024-03-20/mi2log/diag_log_sm05_2024-03-20_18-05-42.mi2log /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm05/#02/raw/diag_log_sm05_2024-03-20_18-05-42.mi2log
#    --- sm06
#     makedir: /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm06/#01/raw
#     mv /home/wmnlab/F/database/2024-03-20/mi2log/diag_log_sm06_2024-03-20_15-23-10.mi2log /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm06/#01/raw/diag_log_sm06_2024-03-20_15-23-10.mi2log
#     makedir: /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm06/#02/raw
#     mv /home/wmnlab/F/database/2024-03-20/mi2log/diag_log_sm06_2024-03-20_18-05-42.mi2log /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm06/#02/raw/diag_log_sm06_2024-03-20_18-05-42.mi2log
#    --- sm07
#     makedir: /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm07/#01/raw
#     mv /home/wmnlab/F/database/2024-03-20/mi2log/diag_log_sm07_2024-03-20_15-23-10.mi2log /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm07/#01/raw/diag_log_sm07_2024-03-20_15-23-10.mi2log
#     makedir: /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm07/#02/raw
#     mv /home/wmnlab/F/database/2024-03-20/mi2log/diag_log_sm07_2024-03-20_18-05-42.mi2log /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm07/#02/raw/diag_log_sm07_2024-03-20_18-05-42.mi2log
#    --- sm08
#     makedir: /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm08/#01/raw
#     mv /home/wmnlab/F/database/2024-03-20/mi2log/diag_log_sm08_2024-03-20_15-23-10.mi2log /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm08/#01/raw/diag_log_sm08_2024-03-20_15-23-10.mi2log
#     makedir: /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm08/#02/raw
#     mv /home/wmnlab/F/database/2024-03-20/mi2log/diag_log_sm08_2024-03-20_18-05-42.mi2log /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm08/#02/raw/diag_log_sm08_2024-03-20_18-05-42.mi2log
#   ------------------
#   mi2log_xml (18)
#    --- sm00
#     mv /home/wmnlab/F/database/2024-03-20/mi2log_xml/diag_log_sm00_2024-03-20_15-23-10.xml /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm00/#01/raw/diag_log_sm00_2024-03-20_15-23-10.xml
#     mv /home/wmnlab/F/database/2024-03-20/mi2log_xml/diag_log_sm00_2024-03-20_18-05-42.xml /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm00/#02/raw/diag_log_sm00_2024-03-20_18-05-42.xml
#    --- sm01
#     mv /home/wmnlab/F/database/2024-03-20/mi2log_xml/diag_log_sm01_2024-03-20_15-23-10.xml /home/wmnlab/F/database/2024-03-20/UDP_Bandlock_9S_Phone_A/sm01/