# %% [markdown]
# # Description
#
# This is an automation script to categorize raw data captured in each experiment.
#
# This script can be divided into four parts:
#
# - Stage 0: User Settings: Modify settings to fit your experiment data.
# - Stage 1: Collect metadata.
# - Stage 2: Check files to make sure the numbers of each type of files are reasonable.
# - Stage 3: Categorize files in chronological order, and organize with experiment names.
#
# Before you go to stage 3, make sure you have already uploaded (manually or using py-script) all the raw data to database into specific directories, and removed the redundant files manually.

# %%
import os
import yaml
import shutil

# ===================== User Settings =====================
dates = [
    # "2024-03-19",
    # "2024-03-20",
    # "2024-05-14",
    "2024-05-20"
]

target_folders = [
    "mi2log",
    "mi2log_xml",
    "server_pcap",
    "client_pcap",
]

common_folders = [
    "gps",
    "sync",
]

# ===================== Utils =====================
def makedir(dirpath):
    if not os.path.isdir(dirpath):
        print('    makedir:', dirpath)
        os.makedirs(dirpath)

def savecopy(filepath, targetdir, filename):
    # filename can be different from basename of filepath, can be used to rename a file.
    makedir(targetdir)
    print("    cp -p", filepath, os.path.join(targetdir, filename))
    shutil.copy2(filepath, os.path.join(targetdir, filename))  # reserve the last modified datetime and other metadata

def savemove(filepath, targetdir, filename):
    # filename can be different from basename of filepath, can be used to rename a file.
    makedir(targetdir)
    print("    mv", filepath, os.path.join(targetdir, filename))
    shutil.move(filepath, os.path.join(targetdir, filename))

# def delete(filepath):
#     if not os.path.exists(filepath):
#         print("rm: '{}': No such file or directory".format(filepath))
#         return
#     print("rm", filepath)
#     os.remove(filepath)

# def movedir(dirpath, targetdir, dirname):
#     # dirname can be different from basename of dirpath, can be used to rename a directory.
#     makedir(targetdir)
#     print("mv", dirpath, os.path.join(targetdir, dirname))
#     shutil.move(dirpath, os.path.join(targetdir, dirname))

# def copydir(dirpath, targetdir, dirname):
#     # dirname can be different from basename of dirpath, can be used to rename a directory.
#     makedir(targetdir)
#     print("copy", dirpath, os.path.join(targetdir, dirname))
#     shutil.copytree(dirpath, os.path.join(targetdir, dirname))

def deletedir_empty(dirpath):
    if not os.path.exists(dirpath):
        print("rmdir: '{}': No such file or directory".format(dirpath))
        return
    print("rmdir", dirpath)
    os.rmdir(dirpath)

# def deletedir_nonempty(dirpath):
#     if not os.path.exists(dirpath):
#         print("rm -rf: '{}': No such file or directory".format(dirpath))
#         return
#     print("rm -rf", dirpath)
#     shutil.rmtree(dirpath, ignore_errors=True)

def get_folder_size(folder_path):
    total_size = 0
    for dirpath, dirnames, filenames in os.walk(folder_path):
        for f in filenames:
            fp = os.path.join(dirpath, f)
            # 跳過符號連結
            if not os.path.islink(fp):
                total_size += os.path.getsize(fp)
    unit_mapping = {0: 'bytes', 1: 'KB', 2: 'MB', 3: 'GB', 4: 'TB', 5: 'PB'}
    cnt = 0
    while total_size > 1000:
        total_size /= 1000
        cnt += 1
    unit = unit_mapping[cnt]
    total_size = f'{round(total_size, 2)} {unit}'
    return total_size

def get_file_size(file_path):
    if os.path.isfile(file_path):
        size = os.path.getsize(file_path)
        unit_mapping = {0: 'bytes', 1: 'KB', 2: 'MB', 3: 'GB', 4: 'TB', 5: 'PB'}
        cnt = 0
        while size > 1000:
            size /= 1000
            cnt += 1
        unit = unit_mapping[cnt]
        size = f'{round(size, 2)} {unit}'
        return size
    else:
        raise ValueError(f"{file_path} is not a valid file.")

def get_size(path):
    if os.path.isdir(path):
        return get_folder_size(path)
    elif os.path.isfile(path):
        return get_file_size(path)
    else:
        raise ValueError(f"{path} is not a valid file or directory.")

# %% [markdown]
# # Stage 1: Collect Metadata

# %%
dates = sorted(dates)
with open(os.path.join(os.getcwd(), "db_path.txt"), "r") as f:
        PATHS_TO_DATABASE = [s.strip() for s in f.readlines()]
    
date_paths = []

for date in dates:
    not_found_in_database = []
    
    for db_path in PATHS_TO_DATABASE:
        date_path = os.path.join(db_path, date)
        if os.path.isdir(date_path):
            date_paths.append(date_path)
        else:
            not_found_in_database.append(date_path)
    
    if len(not_found_in_database) == len(PATHS_TO_DATABASE):
        error_message = "[Errno 2] No such file or directory:\n"
        for date_path in not_found_in_database:
            error_message += "  '{}'\n".format(date_path)
        raise FileNotFoundError(error_message.strip())

metadatas = {}

for i, date_path in enumerate(date_paths):
    print('------------------')
    print(os.path.basename(date_path), ': ', os.path.dirname(date_path), sep='')
    
    yml_file = os.path.join(date_path, os.path.basename(date_path) + '.yml')
    with open(yml_file, 'r') as f:
        data = yaml.safe_load(f)
    
    metadatas[date_path] = [0]
    
    for j, (exp_name, exp) in enumerate(data.items()):
        if j > 0: print('  ------------------')
        print(' ', exp_name, '->', 'Skip:', exp['skip'], '|', 'UE:', exp['ue'], '|', 'Laptop:', exp['laptop'], '|', 'Route:', exp['route'])
        print('   ', exp['devices'])
        if exp['skip']:
            continue
        trips = []
        for key, value in exp['ods'].items():
            print('     ', key, value)
            if key > 0: trips.append(f'#{key:02d}')
        
        metadatas[date_path].append({
            'exp_name': exp_name,
            'ue': exp['ue'],
            'laptop': exp['laptop'],
            'route': exp['route'],
            'devices': list(exp['devices']),
            'trips': trips[:]
        })
        metadatas[date_path][0] += len(trips)
    
    if i == len(date_paths) - 1: print('------------------')
# Out:
# ------------------
# 2024-05-20: /home/wmnlab/E/database
#   Modem_Action_Test_v6_A -> Skip: False | UE: Modem | Laptop: lpt3 | Route: BR
#     {'qc00': 'B1B8', 'qc01': 'LTE', 'qc02': 'DBL_v6_NSA', 'qc05': 'DBL_v6_LTE'}
#       0 ['起站', '迄站', '出發時間(hh:mm)', '備註']
#       1 ['萬芳醫院', '動物園', '15:31', []]
#       2 ['動物園', '萬芳醫院', '15:39', []]
#       3 ['萬芳醫院', '動物園', '15:50', []]
#       4 ['動物園', '萬芳醫院', '15:58', []]
#       5 ['萬芳醫院', '動物園', '16:05', []]
#       6 ['動物園', '萬芳醫院', '16:14', []]
#       7 ['萬芳醫院', '動物園', '16:25', []]
#       8 ['動物園', '萬芳醫院', '16:35', []]
#       9 ['萬芳醫院', '動物園', '16:43', []]
#       10 ['動物園', '萬芳醫院', '16:51', []]
# ------------------

# %% [markdown]
# # Stage 2: Check Files
#
# 檢查資料的數量是否正確
#
# - mi2log, mi2log_xml: 機台數量*總趟次
# - client_pcap: 機台數量*總趟次 (Bilink)
# - server_pcap: 機台數量*總趟次\*2 or 1 (Uplink/Downlink, Bi-link)

# %%
for i, (date_path, metadata) in enumerate(metadatas.items()):
    print('-----------------------------')
    print(date_path, '({})'.format(metadata[0]), get_size(date_path))
    
    for j, exp in enumerate(metadata[1:]):
        if j > 0: print('  -----------------------------')
        print(' ', exp['exp_name'], '->', 'UE:', exp['ue'], '|', 'Laptop:', exp['laptop'], '|', 'Route:', exp['route'])
        print('   ', len(exp['devices']), exp['devices'])
        print('     ', len(exp['trips']), exp['trips'])
    
    for target_folder in target_folders:
        filenames = sorted(os.listdir(os.path.join(date_path, target_folder)))
        print('  ------------------ target folder')
        print(' ', target_folder, '({})'.format(len(filenames)), get_size(os.path.join(date_path, target_folder)))
        for filename in filenames:
            print('   ', filename, get_size(os.path.join(date_path, target_folder, filename)))
    
    for common_folder in common_folders:
        if not os.path.isdir(os.path.join(date_path, common_folder)):
            print('  ------------------ common folder')
            print(' ', common_folder, 'does not exist!')
            continue
        filenames = sorted(os.listdir(os.path.join(date_path, common_folder)))
        print('  ------------------ common folder')
        print(' ', common_folder, '({})'.format(len(filenames)), get_size(os.path.join(date_path, common_folder)))
        for filename in filenames:
            print('   ', filename, get_size(os.path.join(date_path, common_folder, filename)))
    
    if i == len(date_paths) - 1: print('-----------------------------')
# Out:
# -----------------------------
# /home/wmnlab/E/database/2024-05-20 (10) 8.75 GB
#   Modem_Action_Test_v6_A -> UE: Modem | Laptop: lpt3 | Route: BR
#     4 ['qc00', 'qc01', 'qc02', 'qc05']
#       10 ['#01', '#02', '#03', '#04', '#05', '#06', '#07', '#08', '#09', '#10']
#   ------------------ target folder
#   mi2log (40) 17.33 MB
#     diag_log_qc00_2024-05-20_15-30-55.mi2log 589.09 KB
#     diag_log_qc00_2024-05-20_15-39-09.mi2log 563.92 KB
#     diag_log_qc00_2024-05-20_15-50-24.mi2log 680.91 KB
#     diag_log_qc00_2024-05-20_15-58-27.mi2log 573.81 KB
#     diag_log_qc00_2024-05-20_16-05-22.mi2log 656.75 KB
#     diag_log_qc00_2024-05-20_16-14-19.mi2log 663.6 KB
#     diag_log_qc00_2024-05-20_16-25-06.mi2log 598.42 KB
#     diag_log_qc00_2024-05-20_16-35-51.mi2log 520.74 KB
#     diag_log_qc00_2024-05-20_16-43-18.mi2log 648.52 KB
#     diag_log_qc00_2024-05-20_16-51-20.mi2log 566.22 KB
#     diag_log_qc01_2024-05-20_15-30-55.mi2log 337.87 KB
#     diag_log_qc01_2024-05-20_15-39-09.mi2log 315.86 KB
#     diag_log_qc01_2024-05-20_15-50-24.mi2log 322.18 KB
#     diag_log_qc01_2024-05-20_15-58-27.mi2log 329.9 KB
#     diag_log_qc01_2024-05-20_16-05-22.mi2log 333.49 KB
#     diag_log_qc01_2024-05-20_16-14-19.mi2log 270.67 KB
#     diag_log_qc01_2024-05-20_16-25-06.mi2log 445.76 KB
#     diag_log_qc01_2024-05-20_16-35-51.mi2log 317.52 KB
#     diag_log_qc01_2024-05-20_16-43-18.mi2log 336.15 KB
#     diag_log_qc01_2024-05-20_16-51-20.mi2log 341.2 KB
#     diag_log_qc02_2024-05-20_15-31-01.mi2log 618.5 KB
#     diag_log_qc02_2024-05-20_15-39-11.mi2log 589.82 KB
#     diag_log_qc02_2024-05-20_15-50-26.mi2log 602.11 KB
#     diag_log_qc02_2024-05-20_15-58-30.mi2log 548.86 KB
#     diag_log_qc02_2024-05-20_16-05-26.mi2log 602.11 KB
#     diag_log_qc02_2024-05-20_16-14-22.mi2log 565.25 KB
#     diag_log_qc02_2024-05-20_16-25-08.mi2log 110.59 KB
#     diag_log_qc02_2024-05-20_16-35-53.mi2log 573.44 KB
#     diag_log_qc02_2024-05-20_16-43-21.mi2log 610.3 KB
#     diag_log_qc02_2024-05-20_16-51-23.mi2log 532.48 KB
#     diag_log_qc05_2024-05-20_15-31-01.mi2log 196.61 KB
#     diag_log_qc05_2024-05-20_15-39-11.mi2log 221.18 KB
#     diag_log_qc05_2024-05-20_15-50-26.mi2log 401.41 KB
#     diag_log_qc05_2024-05-20_15-58-30.mi2log 225.28 KB
#     diag_log_qc05_2024-05-20_16-05-26.mi2log 401.41 KB
#     diag_log_qc05_2024-05-20_16-14-22.mi2log 217.09 KB
#     diag_log_qc05_2024-05-20_16-25-08.mi2log 356.35 KB
#     diag_log_qc05_2024-05-20_16-35-53.mi2log 221.18 KB
#     diag_log_qc05_2024-05-20_16-43-21.mi2log 139.26 KB
#     diag_log_qc05_2024-05-20_16-51-23.mi2log 184.32 KB
#   ------------------ target folder
#   mi2log_xml (40) 1.53 GB
#     diag_log_qc00_2024-05-20_15-30-55.xml 50.92 MB
#     diag_log_qc00_2024-05-20_15-39-09.xml 57.7 MB
#     diag_log_qc00_2024-05-20_15-50-24.xml 99.63 MB
#     diag_log_qc00_2024-05-20_15-58-27.xml 69.51 MB
#     diag_log_qc00_2024-05-20_16-05-22.xml 88.49 MB
#     diag_log_qc00_2024-05-20_16-14-19.xml 115.87 MB
#     diag_log_qc00_2024-05-20_16-25-06.xml 72.18 MB
#     diag_log_qc00_2024-05-20_16-35-51.xml 44.28 MB
#     diag_log_qc00_2024-05-20_16-43-18.xml 81.11 MB
#     diag_log_qc00_2024-05-20_16-51-20.xml 68.12 MB
#     diag_log_qc01_2024-05-20_15-30-55.xml 13.52 MB
#     diag_log_qc01_2024-05-20_15-39-09.xml 11.3 MB
#     diag_log_qc01_2024-05-20_15-50-24.xml 10.94 MB
#     diag_log_qc01_2024-05-20_15-58-27.xml 12.1 MB
#     diag_log_qc01_2024-05-20_16-05-22.xml 15.0 MB
#     diag_log_qc01_2024-05-20_16-14-19.xml 11.69 MB
#     diag_log_qc01_2024-05-20_16-25-06.xml 13.35 MB
#     diag_log_qc01_2024-05-20_16-35-51.xml 11.94 MB
#     diag_log_qc01_2024-05-20_16-43-18.xml 12.51 MB
#     diag_log_qc01_2024-05-20_16-51-20.xml 10.61 MB
#     diag_log_qc02_2024-05-20_15-31-01.xml 66.41 MB
#     diag_log_qc02_2024-05-20_15-39-11.xml 65.81 MB
#     diag_log_qc02_2024-05-20_15-50-26.xml 60.1 MB
#     diag_log_qc02_2024-05-20_15-58-30.xml 50.0 MB
#     diag_log_qc02_2024-05-20_16-05-26.xml 62.23 MB
#     diag_log_qc02_2024-05-20_16-14-22.xml 65.16 MB
#     diag_log_qc02_2024-05-20_16-25-08.xml 9.6 MB
#     diag_log_qc02_2024-05-20_16-35-53.xml 63.51 MB
#     diag_log_qc02_2024-05-20_16-43-21.xml 62.25 MB
#     diag_log_qc02_2024-05-20_16-51-23.xml 49.98 MB
#     diag_log_qc05_2024-05-20_15-31-01.xml 11.19 MB
#     diag_log_qc05_2024-05-20_15-39-11.xml 9.53 MB
#     diag_log_qc05_2024-05-20_15-50-26.xml 12.78 MB
#     diag_log_qc05_2024-05-20_15-58-30.xml 10.08 MB
#     diag_log_qc05_2024-05-20_16-05-26.xml 13.9 MB
#     diag_log_qc05_2024-05-20_16-14-22.xml 10.76 MB
#     diag_log_qc05_2024-05-20_16-25-08.xml 10.86 MB
#     diag_log_qc05_2024-05-20_16-35-53.xml 8.67 MB
#     diag_log_qc05_2024-05-20_16-43-21.xml 6.52 MB
#     diag_log_qc05_2024-05-20_16-51-23.xml 9.63 MB
#   ------------------ target folder
#   server_pcap (40) 3.6 GB
#     server_pcap_BL_qc00_3270_3271_2024-05-20_15-31-00_sock.pcap 93.47 MB
#     server_pcap_BL_qc00_3270_3271_2024-05-20_15-39-12_sock.pcap 88.39 MB
#     server_pcap_BL_qc00_3270_3271_2024-05-20_15-50-27_sock.pcap 95.39 MB
#     server_pcap_BL_qc00_3270_3271_2024-05-20_15-58-31_sock.pcap 87.78 MB
#     server_pcap_BL_qc00_3270_3271_2024-05-20_16-05-26_sock.pcap 91.15 MB
#     server_pcap_BL_qc00_3270_3271_2024-05-20_16-14-22_sock.pcap 85.22 MB
#     server_pcap_BL_qc00_3270_3271_2024-05-20_16-25-09_sock.pcap 91.29 MB
#     server_pcap_BL_qc00_3270_3271_2024-05-20_16-35-54_sock.pcap 87.58 MB
#     server_pcap_BL_qc00_3270_3271_2024-05-20_16-43-21_sock.pcap 93.04 MB
#     server_pcap_BL_qc00_3270_3271_2024-05-20_16-51-24_sock.pcap 86.33 MB
#     server_pcap_BL_qc01_3272_3273_2024-05-20_15-31-00_sock.pcap 93.47 MB
#     server_pcap_BL_qc01_3272_3273_2024-05-20_15-39-12_sock.pcap 88.39 MB
#     server_pcap_BL_qc01_3272_3273_2024-05-20_15-50-27_sock.pcap 95.4 MB
#     server_pcap_BL_qc01_3272_3273_2024-05-20_15-58-31_sock.pcap 87.95 MB
#     server_pcap_BL_qc01_3272_3273_2024-05-20_16-05-26_sock.pcap 91.23 MB
#     server_pcap_BL_qc01_3272_3273_2024-05-20_16-14-22_sock.pcap 85.46 MB
#     server_pcap_BL_qc01_3272_3273_2024-05-20_16-25-09_sock.pcap 91.35 MB
#     server_pcap_BL_qc01_3272_3273_2024-05-20_16-35-54_sock.pcap 87.58 MB
#     server_pcap_BL_qc01_3272_3273_2024-05-20_16-43-21_sock.pcap 93.03 MB
#     server_pcap_BL_qc01_3272_3273_2024-05-20_16-51-24_sock.pcap 86.39 MB
#     server_pcap_BL_qc02_3274_3275_2024-05-20_15-31-00_sock.pcap 93.64 MB
#     server_pcap_BL_qc02_3274_3275_2024-05-20_15-39-12_sock.pcap 88.18 MB
#     server_pcap_BL_qc02_3274_3275_2024-05-20_15-50-27_sock.pcap 95.4 MB
#     server_pcap_BL_qc02_3274_3275_2024-05-20_15-58-31_sock.pcap 87.8 MB
#     server_pcap_BL_qc02_3274_3275_2024-05-20_16-05-26_sock.pcap 91.15 MB
#     server_pcap_BL_qc02_3274_3275_2024-05-20_16-14-22_sock.pcap 85.19 MB
#     server_pcap_BL_qc02_3274_3275_2024-05-20_16-25-09_sock.pcap 91.36 MB
#     server_pcap_BL_qc02_3274_3275_2024-05-20_16-35-54_sock.pcap 87.58 MB
#     server_pcap_BL_qc02_3274_3275_2024-05-20_16-43-21_sock.pcap 92.99 MB
#     server_pcap_BL_qc02_3274_3275_2024-05-20_16-51-24_sock.pcap 86.34 MB
#     server_pcap_BL_qc05_3280_3281_2024-05-20_15-31-00_sock.pcap 93.59 MB
#     server_pcap_BL_qc05_3280_3281_2024-05-20_15-39-12_sock.pcap 88.34 MB
#     server_pcap_BL_qc05_3280_3281_2024-05-20_15-50-27_sock.pcap 95.4 MB
#     server_pcap_BL_qc05_3280_3281_2024-05-20_15-58-31_sock.pcap 87.8 MB
#     server_pcap_BL_qc05_3280_3281_2024-05-20_16-05-26_sock.pcap 91.15 MB
#     server_pcap_BL_qc05_3280_3281_2024-05-20_16-14-22_sock.pcap 85.33 MB
#     server_pcap_BL_qc05_3280_3281_2024-05-20_16-25-09_sock.pcap 91.35 MB
#     server_pcap_BL_qc05_3280_3281_2024-05-20_16-35-54_sock.pcap 87.57 MB
#     server_pcap_BL_qc05_3280_3281_2024-05-20_16-43-21_sock.pcap 93.05 MB
#     server_pcap_BL_qc05_3280_3281_2024-05-20_16-51-24_sock.pcap 86.31 MB
#   ------------------ target folder
#   client_pcap (40) 3.59 GB
#     client_pcap_BL_qc00_3270_3271_2024-05-20_15-30-58_sock.pcap 93.66 MB
#     client_pcap_BL_qc00_3270_3271_2024-05-20_15-39-10_sock.pcap 88.16 MB
#     client_pcap_BL_qc00_3270_3271_2024-05-20_15-50-25_sock.pcap 95.56 MB
#     client_pcap_BL_qc00_3270_3271_2024-05-20_15-58-29_sock.pcap 87.95 MB
#     client_pcap_BL_qc00_3270_3271_2024-05-20_16-05-24_sock.pcap 91.06 MB
#     client_pcap_BL_qc00_3270_3271_2024-05-20_16-14-20_sock.pcap 85.57 MB
#     client_pcap_BL_qc00_3270_3271_2024-05-20_16-25-07_sock.pcap 91.26 MB
#     client_pcap_BL_qc00_3270_3271_2024-05-20_16-35-52_sock.pcap 87.53 MB
#     client_pcap_BL_qc00_3270_3271_2024-05-20_16-43-19_sock.pcap 93.01 MB
#     client_pcap_BL_qc00_3270_3271_2024-05-20_16-51-21_sock.pcap 86.46 MB
#     client_pcap_BL_qc01_3272_3273_2024-05-20_15-30-58_sock.pcap 93.45 MB
#     client_pcap_BL_qc01_3272_3273_2024-05-20_15-39-10_sock.pcap 88.38 MB
#     client_pcap_BL_qc01_3272_3273_2024-05-20_15-50-25_sock.pcap 95.35 MB
#     client_pcap_BL_qc01_3272_3273_2024-05-20_15-58-29_sock.pcap 87.47 MB
#     client_pcap_BL_qc01_3272_3273_2024-05-20_16-05-24_sock.pcap 90.79 MB
#     client_pcap_BL_qc01_3272_3273_2024-05-20_16-14-20_sock.pcap 84.8 MB
#     client_pcap_BL_qc01_3272_3273_2024-05-20_16-25-07_sock.pcap 91.34 MB
#     client_pcap_BL_qc01_3272_3273_2024-05-20_16-35-52_sock.pcap 87.53 MB
#     client_pcap_BL_qc01_3272_3273_2024-05-20_16-43-19_sock.pcap 93.03 MB
#     client_pcap_BL_qc01_3272_3273_2024-05-20_16-51-21_sock.pcap 85.78 MB
#     client_pcap_BL_qc02_3274_3275_2024-05-20_15-30-58_sock.pcap 93.18 MB
#     client_pcap_BL_qc02_3274_3275_2024-05-20_15-39-10_sock.pcap 88.15 MB
#     client_pcap_BL_qc02_3274_3275_2024-05-20_15-50-25_sock.pcap 95.14 MB
#     client_pcap_BL_qc02_3274_3275_2024-05-20_15-58-29_sock.pcap 87.71 MB
#     client_pcap_BL_qc02_3274_3275_2024-05-20_16-05-24_sock.pcap 90.91 MB
#     client_pcap_BL_qc02_3274_3275_2024-05-20_16-14-20_sock.pcap 84.69 MB
#     client_pcap_BL_qc02_3274_3275_2024-05-20_16-25-07_sock.pcap 91.11 MB
#     client_pcap_BL_qc02_3274_3275_2024-05-20_16-35-52_sock.pcap 87.3 MB
#     client_pcap_BL_qc02_3274_3275_2024-05-20_16-43-19_sock.pcap 92.29 MB
#     client_pcap_BL_qc02_3274_3275_2024-05-20_16-51-21_sock.pcap 85.99 MB
#     client_pcap_BL_qc05_3280_3281_2024-05-20_15-30-58_sock.pcap 92.69 MB
#     client_pcap_BL_qc05_3280_3281_2024-05-20_15-39-10_sock.pcap 87.37 MB
#     client_pcap_BL_qc05_3280_3281_2024-05-20_15-50-25_sock.pcap 95.35 MB
#     client_pcap_BL_qc05_3280_3281_2024-05-20_15-58-29_sock.pcap 87.95 MB
#     client_pcap_BL_qc05_3280_3281_2024-05-20_16-05-24_sock.pcap 91.13 MB
#     client_pcap_BL_qc05_3280_3281_2024-05-20_16-14-20_sock.pcap 84.84 MB
#     client_pcap_BL_qc05_3280_3281_2024-05-20_16-25-07_sock.pcap 91.34 MB
#     client_pcap_BL_qc05_3280_3281_2024-05-20_16-35-52_sock.pcap 87.49 MB
#     client_pcap_BL_qc05_3280_3281_2024-05-20_16-43-19_sock.pcap 93.02 MB
#     client_pcap_BL_qc05_3280_3281_2024-05-20_16-51-21_sock.pcap 86.0 MB
#   ------------------ common folder
#   gps does not exist!
#   ------------------ common folder
#   sync does not exist!
# -----------------------------

# %% [markdown]
# # Stage 3: Categorize

# %%
for i, (date_path, metadata) in enumerate(metadatas.items()):
    print('------------------')
    print(date_path, '({})'.format(metadata[0]))
    
    for j, exp in enumerate(metadata[1:]):
        if j > 0: print('  ------------------')
        print(' ', exp['exp_name'], '->', 'UE:', exp['ue'], '|', 'Laptop:', exp['laptop'], '|', 'Route:', exp['route'])
        print('   ', len(exp['devices']), exp['devices'])
        print('     ', len(exp['trips']), exp['trips'])
        for target_folder in target_folders:
            src_dirpath = os.path.join(date_path, target_folder)
            print('  ------------------')
            print(' ', target_folder, '({})'.format(len(os.listdir(src_dirpath))))
            for dev in exp['devices']:
                print('   ---', dev)
                filenames = sorted([s for s in os.listdir(src_dirpath) if dev in s])
                for trip in exp['trips']:
                    filename = filenames.pop(0)
                    dest_dirpath = os.path.join(date_path, exp['exp_name'], dev, trip, 'raw')
                    savemove(os.path.join(src_dirpath, filename), dest_dirpath, filename)
    
    if i == len(date_paths) - 1: print('------------------')

for i, (date_path, metadata) in enumerate(metadatas.items()):
    for target_folder in target_folders:
        src_dirpath = os.path.join(date_path, target_folder)
        deletedir_empty(src_dirpath)
# Out:
# ------------------
# /home/wmnlab/E/database/2024-05-20 (10)
#   Modem_Action_Test_v6_A -> UE: Modem | Laptop: lpt3 | Route: BR
#     4 ['qc00', 'qc01', 'qc02', 'qc05']
#       10 ['#01', '#02', '#03', '#04', '#05', '#06', '#07', '#08', '#09', '#10']
#   ------------------
#   mi2log (40)
#    --- qc00
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#01/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc00_2024-05-20_15-30-55.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#01/raw/diag_log_qc00_2024-05-20_15-30-55.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#02/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc00_2024-05-20_15-39-09.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#02/raw/diag_log_qc00_2024-05-20_15-39-09.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#03/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc00_2024-05-20_15-50-24.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#03/raw/diag_log_qc00_2024-05-20_15-50-24.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#04/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc00_2024-05-20_15-58-27.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#04/raw/diag_log_qc00_2024-05-20_15-58-27.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#05/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc00_2024-05-20_16-05-22.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#05/raw/diag_log_qc00_2024-05-20_16-05-22.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#06/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc00_2024-05-20_16-14-19.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#06/raw/diag_log_qc00_2024-05-20_16-14-19.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#07/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc00_2024-05-20_16-25-06.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#07/raw/diag_log_qc00_2024-05-20_16-25-06.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#08/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc00_2024-05-20_16-35-51.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#08/raw/diag_log_qc00_2024-05-20_16-35-51.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#09/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc00_2024-05-20_16-43-18.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#09/raw/diag_log_qc00_2024-05-20_16-43-18.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#10/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc00_2024-05-20_16-51-20.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#10/raw/diag_log_qc00_2024-05-20_16-51-20.mi2log
#    --- qc01
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#01/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc01_2024-05-20_15-30-55.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#01/raw/diag_log_qc01_2024-05-20_15-30-55.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#02/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc01_2024-05-20_15-39-09.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#02/raw/diag_log_qc01_2024-05-20_15-39-09.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#03/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc01_2024-05-20_15-50-24.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#03/raw/diag_log_qc01_2024-05-20_15-50-24.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#04/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc01_2024-05-20_15-58-27.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#04/raw/diag_log_qc01_2024-05-20_15-58-27.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#05/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc01_2024-05-20_16-05-22.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#05/raw/diag_log_qc01_2024-05-20_16-05-22.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#06/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc01_2024-05-20_16-14-19.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#06/raw/diag_log_qc01_2024-05-20_16-14-19.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#07/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc01_2024-05-20_16-25-06.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#07/raw/diag_log_qc01_2024-05-20_16-25-06.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#08/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc01_2024-05-20_16-35-51.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#08/raw/diag_log_qc01_2024-05-20_16-35-51.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#09/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc01_2024-05-20_16-43-18.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#09/raw/diag_log_qc01_2024-05-20_16-43-18.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#10/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc01_2024-05-20_16-51-20.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#10/raw/diag_log_qc01_2024-05-20_16-51-20.mi2log
#    --- qc02
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#01/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc02_2024-05-20_15-31-01.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#01/raw/diag_log_qc02_2024-05-20_15-31-01.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#02/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc02_2024-05-20_15-39-11.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#02/raw/diag_log_qc02_2024-05-20_15-39-11.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#03/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc02_2024-05-20_15-50-26.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#03/raw/diag_log_qc02_2024-05-20_15-50-26.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#04/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc02_2024-05-20_15-58-30.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#04/raw/diag_log_qc02_2024-05-20_15-58-30.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#05/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc02_2024-05-20_16-05-26.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#05/raw/diag_log_qc02_2024-05-20_16-05-26.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#06/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc02_2024-05-20_16-14-22.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#06/raw/diag_log_qc02_2024-05-20_16-14-22.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#07/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc02_2024-05-20_16-25-08.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#07/raw/diag_log_qc02_2024-05-20_16-25-08.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#08/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc02_2024-05-20_16-35-53.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#08/raw/diag_log_qc02_2024-05-20_16-35-53.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#09/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc02_2024-05-20_16-43-21.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#09/raw/diag_log_qc02_2024-05-20_16-43-21.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#10/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc02_2024-05-20_16-51-23.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#10/raw/diag_log_qc02_2024-05-20_16-51-23.mi2log
#    --- qc05
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#01/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc05_2024-05-20_15-31-01.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#01/raw/diag_log_qc05_2024-05-20_15-31-01.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#02/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc05_2024-05-20_15-39-11.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#02/raw/diag_log_qc05_2024-05-20_15-39-11.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#03/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc05_2024-05-20_15-50-26.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#03/raw/diag_log_qc05_2024-05-20_15-50-26.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#04/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc05_2024-05-20_15-58-30.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#04/raw/diag_log_qc05_2024-05-20_15-58-30.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#05/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc05_2024-05-20_16-05-26.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#05/raw/diag_log_qc05_2024-05-20_16-05-26.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#06/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc05_2024-05-20_16-14-22.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#06/raw/diag_log_qc05_2024-05-20_16-14-22.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#07/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc05_2024-05-20_16-25-08.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#07/raw/diag_log_qc05_2024-05-20_16-25-08.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#08/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc05_2024-05-20_16-35-53.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#08/raw/diag_log_qc05_2024-05-20_16-35-53.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#09/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc05_2024-05-20_16-43-21.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#09/raw/diag_log_qc05_2024-05-20_16-43-21.mi2log
#     makedir: /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#10/raw
#     mv /home/wmnlab/E/database/2024-05-20/mi2log/diag_log_qc05_2024-05-20_16-51-23.mi2log /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#10/raw/diag_log_qc05_2024-05-20_16-51-23.mi2log
#   ------------------
#   mi2log_xml (40)
#    --- qc00
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc00_2024-05-20_15-30-55.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#01/raw/diag_log_qc00_2024-05-20_15-30-55.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc00_2024-05-20_15-39-09.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#02/raw/diag_log_qc00_2024-05-20_15-39-09.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc00_2024-05-20_15-50-24.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#03/raw/diag_log_qc00_2024-05-20_15-50-24.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc00_2024-05-20_15-58-27.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#04/raw/diag_log_qc00_2024-05-20_15-58-27.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc00_2024-05-20_16-05-22.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#05/raw/diag_log_qc00_2024-05-20_16-05-22.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc00_2024-05-20_16-14-19.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#06/raw/diag_log_qc00_2024-05-20_16-14-19.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc00_2024-05-20_16-25-06.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#07/raw/diag_log_qc00_2024-05-20_16-25-06.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc00_2024-05-20_16-35-51.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#08/raw/diag_log_qc00_2024-05-20_16-35-51.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc00_2024-05-20_16-43-18.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#09/raw/diag_log_qc00_2024-05-20_16-43-18.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc00_2024-05-20_16-51-20.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#10/raw/diag_log_qc00_2024-05-20_16-51-20.xml
#    --- qc01
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc01_2024-05-20_15-30-55.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#01/raw/diag_log_qc01_2024-05-20_15-30-55.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc01_2024-05-20_15-39-09.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#02/raw/diag_log_qc01_2024-05-20_15-39-09.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc01_2024-05-20_15-50-24.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#03/raw/diag_log_qc01_2024-05-20_15-50-24.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc01_2024-05-20_15-58-27.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#04/raw/diag_log_qc01_2024-05-20_15-58-27.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc01_2024-05-20_16-05-22.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#05/raw/diag_log_qc01_2024-05-20_16-05-22.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc01_2024-05-20_16-14-19.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#06/raw/diag_log_qc01_2024-05-20_16-14-19.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc01_2024-05-20_16-25-06.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#07/raw/diag_log_qc01_2024-05-20_16-25-06.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc01_2024-05-20_16-35-51.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#08/raw/diag_log_qc01_2024-05-20_16-35-51.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc01_2024-05-20_16-43-18.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#09/raw/diag_log_qc01_2024-05-20_16-43-18.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc01_2024-05-20_16-51-20.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#10/raw/diag_log_qc01_2024-05-20_16-51-20.xml
#    --- qc02
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc02_2024-05-20_15-31-01.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#01/raw/diag_log_qc02_2024-05-20_15-31-01.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc02_2024-05-20_15-39-11.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#02/raw/diag_log_qc02_2024-05-20_15-39-11.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc02_2024-05-20_15-50-26.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#03/raw/diag_log_qc02_2024-05-20_15-50-26.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc02_2024-05-20_15-58-30.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#04/raw/diag_log_qc02_2024-05-20_15-58-30.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc02_2024-05-20_16-05-26.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#05/raw/diag_log_qc02_2024-05-20_16-05-26.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc02_2024-05-20_16-14-22.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#06/raw/diag_log_qc02_2024-05-20_16-14-22.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc02_2024-05-20_16-25-08.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#07/raw/diag_log_qc02_2024-05-20_16-25-08.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc02_2024-05-20_16-35-53.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#08/raw/diag_log_qc02_2024-05-20_16-35-53.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc02_2024-05-20_16-43-21.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#09/raw/diag_log_qc02_2024-05-20_16-43-21.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc02_2024-05-20_16-51-23.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#10/raw/diag_log_qc02_2024-05-20_16-51-23.xml
#    --- qc05
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc05_2024-05-20_15-31-01.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#01/raw/diag_log_qc05_2024-05-20_15-31-01.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc05_2024-05-20_15-39-11.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#02/raw/diag_log_qc05_2024-05-20_15-39-11.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc05_2024-05-20_15-50-26.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#03/raw/diag_log_qc05_2024-05-20_15-50-26.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc05_2024-05-20_15-58-30.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#04/raw/diag_log_qc05_2024-05-20_15-58-30.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc05_2024-05-20_16-05-26.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#05/raw/diag_log_qc05_2024-05-20_16-05-26.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc05_2024-05-20_16-14-22.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#06/raw/diag_log_qc05_2024-05-20_16-14-22.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc05_2024-05-20_16-25-08.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#07/raw/diag_log_qc05_2024-05-20_16-25-08.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc05_2024-05-20_16-35-53.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#08/raw/diag_log_qc05_2024-05-20_16-35-53.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc05_2024-05-20_16-43-21.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#09/raw/diag_log_qc05_2024-05-20_16-43-21.xml
#     mv /home/wmnlab/E/database/2024-05-20/mi2log_xml/diag_log_qc05_2024-05-20_16-51-23.xml /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#10/raw/diag_log_qc05_2024-05-20_16-51-23.xml
#   ------------------
#   server_pcap (40)
#    --- qc00
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc00_3270_3271_2024-05-20_15-31-00_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#01/raw/server_pcap_BL_qc00_3270_3271_2024-05-20_15-31-00_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc00_3270_3271_2024-05-20_15-39-12_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#02/raw/server_pcap_BL_qc00_3270_3271_2024-05-20_15-39-12_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc00_3270_3271_2024-05-20_15-50-27_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#03/raw/server_pcap_BL_qc00_3270_3271_2024-05-20_15-50-27_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc00_3270_3271_2024-05-20_15-58-31_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#04/raw/server_pcap_BL_qc00_3270_3271_2024-05-20_15-58-31_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc00_3270_3271_2024-05-20_16-05-26_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#05/raw/server_pcap_BL_qc00_3270_3271_2024-05-20_16-05-26_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc00_3270_3271_2024-05-20_16-14-22_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#06/raw/server_pcap_BL_qc00_3270_3271_2024-05-20_16-14-22_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc00_3270_3271_2024-05-20_16-25-09_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#07/raw/server_pcap_BL_qc00_3270_3271_2024-05-20_16-25-09_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc00_3270_3271_2024-05-20_16-35-54_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#08/raw/server_pcap_BL_qc00_3270_3271_2024-05-20_16-35-54_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc00_3270_3271_2024-05-20_16-43-21_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#09/raw/server_pcap_BL_qc00_3270_3271_2024-05-20_16-43-21_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc00_3270_3271_2024-05-20_16-51-24_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#10/raw/server_pcap_BL_qc00_3270_3271_2024-05-20_16-51-24_sock.pcap
#    --- qc01
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc01_3272_3273_2024-05-20_15-31-00_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#01/raw/server_pcap_BL_qc01_3272_3273_2024-05-20_15-31-00_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc01_3272_3273_2024-05-20_15-39-12_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#02/raw/server_pcap_BL_qc01_3272_3273_2024-05-20_15-39-12_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc01_3272_3273_2024-05-20_15-50-27_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#03/raw/server_pcap_BL_qc01_3272_3273_2024-05-20_15-50-27_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc01_3272_3273_2024-05-20_15-58-31_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#04/raw/server_pcap_BL_qc01_3272_3273_2024-05-20_15-58-31_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc01_3272_3273_2024-05-20_16-05-26_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#05/raw/server_pcap_BL_qc01_3272_3273_2024-05-20_16-05-26_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc01_3272_3273_2024-05-20_16-14-22_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#06/raw/server_pcap_BL_qc01_3272_3273_2024-05-20_16-14-22_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc01_3272_3273_2024-05-20_16-25-09_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#07/raw/server_pcap_BL_qc01_3272_3273_2024-05-20_16-25-09_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc01_3272_3273_2024-05-20_16-35-54_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#08/raw/server_pcap_BL_qc01_3272_3273_2024-05-20_16-35-54_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc01_3272_3273_2024-05-20_16-43-21_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#09/raw/server_pcap_BL_qc01_3272_3273_2024-05-20_16-43-21_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc01_3272_3273_2024-05-20_16-51-24_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#10/raw/server_pcap_BL_qc01_3272_3273_2024-05-20_16-51-24_sock.pcap
#    --- qc02
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc02_3274_3275_2024-05-20_15-31-00_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#01/raw/server_pcap_BL_qc02_3274_3275_2024-05-20_15-31-00_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc02_3274_3275_2024-05-20_15-39-12_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#02/raw/server_pcap_BL_qc02_3274_3275_2024-05-20_15-39-12_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc02_3274_3275_2024-05-20_15-50-27_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#03/raw/server_pcap_BL_qc02_3274_3275_2024-05-20_15-50-27_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc02_3274_3275_2024-05-20_15-58-31_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#04/raw/server_pcap_BL_qc02_3274_3275_2024-05-20_15-58-31_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc02_3274_3275_2024-05-20_16-05-26_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#05/raw/server_pcap_BL_qc02_3274_3275_2024-05-20_16-05-26_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc02_3274_3275_2024-05-20_16-14-22_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#06/raw/server_pcap_BL_qc02_3274_3275_2024-05-20_16-14-22_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc02_3274_3275_2024-05-20_16-25-09_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#07/raw/server_pcap_BL_qc02_3274_3275_2024-05-20_16-25-09_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc02_3274_3275_2024-05-20_16-35-54_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#08/raw/server_pcap_BL_qc02_3274_3275_2024-05-20_16-35-54_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc02_3274_3275_2024-05-20_16-43-21_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#09/raw/server_pcap_BL_qc02_3274_3275_2024-05-20_16-43-21_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc02_3274_3275_2024-05-20_16-51-24_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#10/raw/server_pcap_BL_qc02_3274_3275_2024-05-20_16-51-24_sock.pcap
#    --- qc05
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc05_3280_3281_2024-05-20_15-31-00_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#01/raw/server_pcap_BL_qc05_3280_3281_2024-05-20_15-31-00_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc05_3280_3281_2024-05-20_15-39-12_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#02/raw/server_pcap_BL_qc05_3280_3281_2024-05-20_15-39-12_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc05_3280_3281_2024-05-20_15-50-27_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#03/raw/server_pcap_BL_qc05_3280_3281_2024-05-20_15-50-27_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc05_3280_3281_2024-05-20_15-58-31_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#04/raw/server_pcap_BL_qc05_3280_3281_2024-05-20_15-58-31_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc05_3280_3281_2024-05-20_16-05-26_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#05/raw/server_pcap_BL_qc05_3280_3281_2024-05-20_16-05-26_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc05_3280_3281_2024-05-20_16-14-22_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#06/raw/server_pcap_BL_qc05_3280_3281_2024-05-20_16-14-22_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc05_3280_3281_2024-05-20_16-25-09_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#07/raw/server_pcap_BL_qc05_3280_3281_2024-05-20_16-25-09_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc05_3280_3281_2024-05-20_16-35-54_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#08/raw/server_pcap_BL_qc05_3280_3281_2024-05-20_16-35-54_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc05_3280_3281_2024-05-20_16-43-21_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#09/raw/server_pcap_BL_qc05_3280_3281_2024-05-20_16-43-21_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/server_pcap/server_pcap_BL_qc05_3280_3281_2024-05-20_16-51-24_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#10/raw/server_pcap_BL_qc05_3280_3281_2024-05-20_16-51-24_sock.pcap
#   ------------------
#   client_pcap (40)
#    --- qc00
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc00_3270_3271_2024-05-20_15-30-58_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#01/raw/client_pcap_BL_qc00_3270_3271_2024-05-20_15-30-58_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc00_3270_3271_2024-05-20_15-39-10_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#02/raw/client_pcap_BL_qc00_3270_3271_2024-05-20_15-39-10_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc00_3270_3271_2024-05-20_15-50-25_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#03/raw/client_pcap_BL_qc00_3270_3271_2024-05-20_15-50-25_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc00_3270_3271_2024-05-20_15-58-29_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#04/raw/client_pcap_BL_qc00_3270_3271_2024-05-20_15-58-29_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc00_3270_3271_2024-05-20_16-05-24_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#05/raw/client_pcap_BL_qc00_3270_3271_2024-05-20_16-05-24_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc00_3270_3271_2024-05-20_16-14-20_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#06/raw/client_pcap_BL_qc00_3270_3271_2024-05-20_16-14-20_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc00_3270_3271_2024-05-20_16-25-07_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#07/raw/client_pcap_BL_qc00_3270_3271_2024-05-20_16-25-07_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc00_3270_3271_2024-05-20_16-35-52_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#08/raw/client_pcap_BL_qc00_3270_3271_2024-05-20_16-35-52_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc00_3270_3271_2024-05-20_16-43-19_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#09/raw/client_pcap_BL_qc00_3270_3271_2024-05-20_16-43-19_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc00_3270_3271_2024-05-20_16-51-21_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc00/#10/raw/client_pcap_BL_qc00_3270_3271_2024-05-20_16-51-21_sock.pcap
#    --- qc01
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc01_3272_3273_2024-05-20_15-30-58_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#01/raw/client_pcap_BL_qc01_3272_3273_2024-05-20_15-30-58_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc01_3272_3273_2024-05-20_15-39-10_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#02/raw/client_pcap_BL_qc01_3272_3273_2024-05-20_15-39-10_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc01_3272_3273_2024-05-20_15-50-25_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#03/raw/client_pcap_BL_qc01_3272_3273_2024-05-20_15-50-25_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc01_3272_3273_2024-05-20_15-58-29_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#04/raw/client_pcap_BL_qc01_3272_3273_2024-05-20_15-58-29_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc01_3272_3273_2024-05-20_16-05-24_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#05/raw/client_pcap_BL_qc01_3272_3273_2024-05-20_16-05-24_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc01_3272_3273_2024-05-20_16-14-20_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#06/raw/client_pcap_BL_qc01_3272_3273_2024-05-20_16-14-20_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc01_3272_3273_2024-05-20_16-25-07_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#07/raw/client_pcap_BL_qc01_3272_3273_2024-05-20_16-25-07_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc01_3272_3273_2024-05-20_16-35-52_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#08/raw/client_pcap_BL_qc01_3272_3273_2024-05-20_16-35-52_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc01_3272_3273_2024-05-20_16-43-19_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#09/raw/client_pcap_BL_qc01_3272_3273_2024-05-20_16-43-19_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc01_3272_3273_2024-05-20_16-51-21_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc01/#10/raw/client_pcap_BL_qc01_3272_3273_2024-05-20_16-51-21_sock.pcap
#    --- qc02
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc02_3274_3275_2024-05-20_15-30-58_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#01/raw/client_pcap_BL_qc02_3274_3275_2024-05-20_15-30-58_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc02_3274_3275_2024-05-20_15-39-10_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#02/raw/client_pcap_BL_qc02_3274_3275_2024-05-20_15-39-10_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc02_3274_3275_2024-05-20_15-50-25_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#03/raw/client_pcap_BL_qc02_3274_3275_2024-05-20_15-50-25_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc02_3274_3275_2024-05-20_15-58-29_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#04/raw/client_pcap_BL_qc02_3274_3275_2024-05-20_15-58-29_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc02_3274_3275_2024-05-20_16-05-24_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#05/raw/client_pcap_BL_qc02_3274_3275_2024-05-20_16-05-24_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc02_3274_3275_2024-05-20_16-14-20_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#06/raw/client_pcap_BL_qc02_3274_3275_2024-05-20_16-14-20_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc02_3274_3275_2024-05-20_16-25-07_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#07/raw/client_pcap_BL_qc02_3274_3275_2024-05-20_16-25-07_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc02_3274_3275_2024-05-20_16-35-52_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#08/raw/client_pcap_BL_qc02_3274_3275_2024-05-20_16-35-52_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc02_3274_3275_2024-05-20_16-43-19_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#09/raw/client_pcap_BL_qc02_3274_3275_2024-05-20_16-43-19_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc02_3274_3275_2024-05-20_16-51-21_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc02/#10/raw/client_pcap_BL_qc02_3274_3275_2024-05-20_16-51-21_sock.pcap
#    --- qc05
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc05_3280_3281_2024-05-20_15-30-58_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#01/raw/client_pcap_BL_qc05_3280_3281_2024-05-20_15-30-58_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc05_3280_3281_2024-05-20_15-39-10_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#02/raw/client_pcap_BL_qc05_3280_3281_2024-05-20_15-39-10_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc05_3280_3281_2024-05-20_15-50-25_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#03/raw/client_pcap_BL_qc05_3280_3281_2024-05-20_15-50-25_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc05_3280_3281_2024-05-20_15-58-29_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#04/raw/client_pcap_BL_qc05_3280_3281_2024-05-20_15-58-29_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc05_3280_3281_2024-05-20_16-05-24_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#05/raw/client_pcap_BL_qc05_3280_3281_2024-05-20_16-05-24_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc05_3280_3281_2024-05-20_16-14-20_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#06/raw/client_pcap_BL_qc05_3280_3281_2024-05-20_16-14-20_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc05_3280_3281_2024-05-20_16-25-07_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#07/raw/client_pcap_BL_qc05_3280_3281_2024-05-20_16-25-07_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc05_3280_3281_2024-05-20_16-35-52_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#08/raw/client_pcap_BL_qc05_3280_3281_2024-05-20_16-35-52_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc05_3280_3281_2024-05-20_16-43-19_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#09/raw/client_pcap_BL_qc05_3280_3281_2024-05-20_16-43-19_sock.pcap
#     mv /home/wmnlab/E/database/2024-05-20/client_pcap/client_pcap_BL_qc05_3280_3281_2024-05-20_16-51-21_sock.pcap /home/wmnlab/E/database/2024-05-20/Modem_Action_Test_v6_A/qc05/#10/raw/client_pcap_BL_qc05_3280_3281_2024-05-20_16-51-21_sock.pcap
# ------------------
# rmdir /home/wmnlab/E/database/2024-05-20/mi2log
# rmdir /home/wmnlab/E/database/2024-05-20/mi2log_xml
# rmdir /home/wmnlab/E/database/2024-05-20/server_pcap
# rmdir /home/wmnlab/E/database/2024-05-20/client_pcap
